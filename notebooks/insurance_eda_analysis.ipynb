# %%
import sys
import os

# Get the current working directory
current_dir = os.getcwd()

# Add the project root directory to the Python path
project_root = os.path.abspath(os.path.join(current_dir, '..'))
sys.path.insert(0, project_root)

# Print the project root to verify
print(f"Project root: {project_root}")

from src.process.pre_process import Pre_processor
from src.visual.visualize import Visualize

file_path = "../data/MachineLearningRating_v3.txt"

# Initialize the preprocessor
preprocessor = Pre_processor(file_path=file_path)

file_path = "../data/MachineLearningRating_v3.txt"

# Read pipe-delimited file
preprocessor.load_data()

# 3. Initial Exploration
preprocessor.initial_exploration()

# 4. Data Quality Checks
preprocessor.data_quality_checks()
# Out:
# Project root: c:\Users\dagi\OneDrive\Desktop\Kifiya\week-3\insurance-risk-eda
# Data loaded successfully.
#
# --- Initial Data Exploration ---
# Shape of the dataset: (1000098, 52)
# ...

# %%
#  Descriptive Stats
preprocessor.descriptive_stats()
# Out:
# --- Descriptive Statistics ---
#        TotalPremium   TotalClaims  CustomValueEstimate
# count  1.000098e+06  1.000098e+06         2.204560e+05
# mean   6.190550e+01  6.486119e+01         2.255311e+05
# std    2.302845e+02  2.384075e+03         5.645157e+05
# min   -7.825768e+02 -1.200241e+04         2.000000e+04
# 25%    0.000000e+00  0.000000e+00         1.350000e+05
# 50%    2.178333e+00  0.000000e+00         2.200000e+05
# 75%    2.192982e+01  0.000000e+00         2.800000e+05
# max    6.528260e+04  3.930921e+05         2.655000e+07

# %%
#initialize the visualizer
visualizer = Visualize(preprocessor.df)

#  Visualize Data
visualizer.univariate_analysis(num_cols = ['TotalPremium', 'TotalClaims', 'CustomValueEstimate'])

# Categorical: Gender, Province, VehicleType
cat_cols = ['Gender', 'Province', 'VehicleType']
visualizer.categorical_analysis(cat_cols=cat_cols)


# Bivariate Analysis – Loss Ratio
visualizer.bivariate_analysis()

# Gender comparison
visualizer.gender_comparison()

#Outlier Detection
visualizer.outlier_detection(num_cols=['TotalPremium', 'TotalClaims', 'CustomValueEstimate'])

# Temporal Analysis
visualizer.temporal_analysis()

# Top 3 Insightful Visualizations (example)
visualizer.top_insights()
# Out:
# --- Univariate Analysis ---
# --- Categorical Analysis ---
# --- Bivariate Analysis: Loss Ratio by Province ---
# --- Gender Comparison of Loss Ratio ---
# --- Outlier Detection ---
# --- Temporal Analysis ---
# --- Top 3 Insightful Visualizations ---
